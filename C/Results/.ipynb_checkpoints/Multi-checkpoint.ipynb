# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
with open('multi.csv','r') as f:
    lines = f.readlines()
    
info = {}
for l in lines:
    a = [a.strip() for a in l.split(',')]
    if a[0] not in info:
        info[a[0]] = {}
    if a[1] not in info[a[0]]:
        info[a[0]][a[1]] = {}
    if a[2] not in info[a[0]][a[1]]:
        info[a[0]][a[1]][a[2]] = [[],[],[]]
    info[a[0]][a[1]][a[2]][0].append(a[3])
    info[a[0]][a[1]][a[2]][1].append(a[4])
    info[a[0]][a[1]][a[2]][2].append(a[5])
    
for a in info.keys():
    for b in info[a].keys():
        for c in info[a][b].keys():
            info[a][b][c][0] = np.mean([float(i) for i in info[a][b][c][0]])
            info[a][b][c][1] = np.mean([float(i) for i in info[a][b][c][1]])
            info[a][b][c][2] = np.mean([float(i) for i in info[a][b][c][2]])

# %%
print(info.keys())
print(info['./vectorized'].keys())
print(info['./vectorized']['32'].keys())
print(info['./vectorized']['32']['32'])
# Out:
# dict_keys(['./vectorized', './multi'])
# dict_keys(['2', '4', '8', '16', '32', '64', '128', '256', '512', '1024', '2048'])
# dict_keys(['1', '2', '4', '8', '16', '32'])
# [14.3167972, 0.0044, 208.319992]

# %%
times = []
idx = 0
for k in info['./vectorized']['2'].keys():
    times.append([])
    for a in info['./vectorized'].keys():
        times[idx].append(info['./vectorized'][a][k][0])
    idx += 1

# %%
print(times)
# Out:
# [[0.032949400000000004, 0.1026154, 0.06084459999999999, 0.045156600000000005, 0.063372, 0.426197, 2.940607, 25.8315086, 243.74918939999998, 2118.9259526, 42599.658012199994, 0.2656458, 0.25596599999999997, 0.9260178, 0.2533434, 0.41923520000000003, 0.3895758, 1.5446186, 13.0176068, 134.6457958, 1113.2806776000002, 19663.731575200003, 0.1490114, 6.4079762, 3.2117846, 0.18925679999999998, 0.3581524, 1.2573720000000002, 1.064396, 6.690597599999999, 68.89157279999999, 576.744604, 10047.6611614, 1.5962124, 8.2678792, 2.3141860000000003, 4.1357042, 4.0522096, 2.4133682, 0.8986471999999999, 3.5131456, 35.467434, 295.93925500000006, 6755.6771754, 2.2570134000000004, 9.460258600000001, 8.8841438, 8.7738038, 8.385563, 5.995416400000001, 4.4253348, 7.0569992, 21.625375799999997, 173.2180116, 3401.9984243999997, 10.658407, 15.972805, 15.523004600000002, 16.4989948, 14.3167972, 12.609005, 9.4672202, 12.4752996, 23.348188600000004, 109.53884119999998, 2271.0947992], [0.032949400000000004, 0.1026154, 0.06084459999999999, 0.045156600000000005, 0.063372, 0.426197, 2.940607, 25.8315086, 243.74918939999998, 2118.9259526, 42599.658012199994, 0.2656458, 0.25596599999999997, 0.9260178, 0.2533434, 0.41923520000000003, 0.3895758, 1.5446186, 13.0176068, 134.6457958, 1113.2806776000002, 19663.731575200003, 0.1490114, 6.4079762, 3.2117846, 0.18925679999999998, 0.3581